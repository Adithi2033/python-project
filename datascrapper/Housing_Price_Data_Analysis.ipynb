# %%
import pandas as pd

# %%
Housing_Price_Data=pd.read_csv('Housing_Price2.csv', sep=';')

# %%
Housing_Price_Data.head()
# Out:
#       Price                                          Broker HouseStatus  \
# 0  $549,000  Brokered by Keller Williams Grand Rapids North    For Sale
# 1  $242,500           Brokered by Carole Wilson Real Estate    For Sale
# 2  $139,900                Brokered by Stephens Real Estate    For Sale
# 3  $130,000       Brokered by Michigan Whitetail Properties    For Sale
# 4  $395,000            Brokered by Chuck Jaqua,Realtor,Inc.    For Sale
#
#                               Address                        Bed      Bath  \
# 0                    Fremont,MI 49412                       9bed  9.5+bath
# 1       3672 Forest DrLupton,MI 48635                       3bed   1.5bath
# 2    903 E Seventh AveNorway,MI 49870                       3bed     1bath
# 3     0 Vl W Olson RdSanford,MI 48657  30.3acre lot30.3 acre lot       NaN
# 4  13972 S 5th StSchoolcraft,MI 49087                       3bed  1.5+bath
#
#                        Spsqft                      SizeAcre,,,,,,,
# ...

# %%
Housing_Price_Data.rename(columns = {'Price;Broker;HouseStatus;Address;Bed;Bath;Spsqft;SizeAcre':'Price'}, inplace = True)

# %%
Housing_Price_Data.rename(columns = {'Unnamed: 1':'Broker','Unnamed: 2':'HouseStatus','Unnamed: 3':'Address','Unnamed: 4':'Bed','Unnamed: 5':'Bath','Unnamed: 6':'Spsqft','Unnamed: 7':'SizeAcre'}, inplace = True)

# %%
Housing_Price_Data.head(11)
# Out:
#          Price                                          Broker HouseStatus  \
# 0     $549,000  Brokered by Keller Williams Grand Rapids North    For Sale
# 1     $242,500           Brokered by Carole Wilson Real Estate    For Sale
# 2     $139,900                Brokered by Stephens Real Estate    For Sale
# 3     $130,000       Brokered by Michigan Whitetail Properties    For Sale
# 4     $395,000            Brokered by Chuck Jaqua,Realtor,Inc.    For Sale
# 5     $239,900                   Brokered by Golden Key Realty  Contingent
# 6     $120,000      Brokered by Keystone Home Group Realty Llc     Pending
# 7     $189,000                Brokered by Big Lake Real Estate    For Sale
# 8   $4,750,000    Brokered by Kidd & Leavy Real Estate Co. Llc    For Sale
# 9      $35,000                Brokered by Re/Max North Country    For Sale
# 10    $749,000                   Brokered by River Oaks Realty    For Sale
#
# ...

# %%
print(Housing_Price_Data.columns.tolist())

# %%
Housing_Price_Data.rename(columns = {'SizeAcre,,,,,,,':'SizeAcre'}, inplace = True)

# %%
Housing_Price_Data['SizeAcre'].astype(str)

# %%
Housing_Price_Data['SizeAcre']=Housing_Price_Data['SizeAcre'].str.replace(',','')

# %%
Housing_Price_Data['Spsqft'].split(",")[0] ‍
# Out:
#   Cell In[68], line 1
#     Housing_Price_Data['Spsqft'].split(",")[0] ‍
#                                                ^
# SyntaxError: invalid character in identifier
